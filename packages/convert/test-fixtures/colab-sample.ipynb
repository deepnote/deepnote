# %% [markdown]
# # Google Colab Notebook
#
# This notebook was created in Google Colab.

# %%
print('Hello from Colab!')
# Out:
# Hello from Colab!

# %%
#@title This is a Colab form cell
#@markdown Enter your name:
name = 'World' #@param {type:"string"}
print(f'Hello, {name}!')
