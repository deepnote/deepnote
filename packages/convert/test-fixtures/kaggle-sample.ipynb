# %% [markdown]
# # Kaggle Notebook
#
# This notebook was created on Kaggle.

# %%
import os
print(os.environ.get('KAGGLE_DATA_PROXY_TOKEN', '/kaggle/input'))
print('/kaggle/working')
# Out:
# /kaggle/input
# /kaggle/working

# %%
# This cell's input is hidden on Kaggle
import pandas as pd
df = pd.read_csv('/kaggle/input/dataset/train.csv')
